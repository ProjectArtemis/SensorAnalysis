# %%
# %pylab inline
import px4tools
import pandas
import os
import pickle
import scipy.interpolate
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import px4tools.version
px4tools.version.git_revision
# Out:
# 'ea072dcdbcaf8c0d0b43e9a6eb16e151f4c06a0e'

# %%
print('Loading dataset')
d_accel = px4tools.ulog.PX4MessageDict({'sensor_accel_0': pandas.read_csv('/home/kabir/kalibration/imu/3/log001_sensor_accel_0.csv')})
d_gyro = px4tools.ulog.PX4MessageDict({'sensor_gyro_0': pandas.read_csv('/home/kabir/kalibration/imu/3/log001_sensor_gyro_0.csv')})
print('Loaded dataset')
          
print('Loading sensor series')
gyro = d_gyro.get_topic('sensor_gyro_0')
accel = d_accel.get_topic('sensor_accel_0')
print('Loaded sensor series')
# Out:
# Loading dataset
# Loaded dataset
# Loading sensor series
# Loaded sensor series

# %%
print('Starting polynomial fitting - Gyroscope')

# Gyroscope
r = {}
plt.figure()
res1 = px4tools.ulog.plot_allan_std_dev(gyro.t_sensor_gyro_0__f_x, min_intervals=4, poly_order=3)
res2 = px4tools.ulog.plot_allan_std_dev(gyro.t_sensor_gyro_0__f_y, min_intervals=4, poly_order=3)
res3 = px4tools.ulog.plot_allan_std_dev(gyro.t_sensor_gyro_0__f_z, min_intervals=4, poly_order=3)

plt.title('Allan standard deviation plot - gyroscope')

for key in res1.keys():
    r['gyroscope_' + key] = [ d[key] for d in [res1, res2, res3] ]
plt.show()
print('Gyroscope analysis :')
print(r)
# Out:
# Starting polynomial fitting - Gyroscope
# Gyroscope analysis :
# {'gyroscope_sig_rrw': [2.389920322860101e-06, 6.4772525358846887e-06, 2.350844608893527e-06], 'gyroscope_tau_0': [1, 1, 1], 'gyroscope_sig_bi': [4.3326798070269529e-05, 6.3073424230320344e-05, 3.5656105119073499e-05], 'gyroscope_tau_1': [80.480167361835385, 17.062090480713476, 63.934712872991526], 'gyroscope_sig_rw': [7.6477766408100103e-05, 6.3838111522093095e-05, 6.0901181629140579e-05], 'gyroscope_tau_2': [1934.0911169035014, 778.62158157988858, 1211.2510790169044]}

# %%
print('Starting polynomial fitting - Accelerometer')
# Accel
r = {}
plt.figure()
res1 = px4tools.ulog.plot_allan_std_dev(accel.t_sensor_accel_0__f_x, min_intervals=9, poly_order=3)
res2 = px4tools.ulog.plot_allan_std_dev(accel.t_sensor_accel_0__f_y, min_intervals=9, poly_order=3)
res3 = px4tools.ulog.plot_allan_std_dev(accel.t_sensor_accel_0__f_z, min_intervals=9, poly_order=3)

plt.title('Allan standard deviation plot - accelerometer')
for key in res1.keys():
    r['accelerometer_' + key] = [ d[key] for d in [res1, res2, res3] ]
plt.show()
print('Accelerometer analysis :')
print(r)
# Out:
# Starting polynomial fitting - Accelerometer
